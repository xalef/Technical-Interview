# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DATA

# %%
data = {
    "account_id": [101, 102, 103, 104, 105],
    "credit_limit": [1000, 2000, 1500, 3000, 1200],
    "current_balance": [200, 1500, 400, 2800, 100],
    "credit_score": [720, 610, 580, 690, 750],
    "default_flag": [0, 1, 0, 1, 0],
}

df = pd.DataFrame(data)

print("Accounts DataFrame:")
print(df)

# %% [markdown]
# Question:
# 1. Create a new column called utilization defined as
# utilization = current_balance / credit_limit.
#
# 2. Then calculate the average utilization separately for accounts that defaulted (default_flag = 1) and those that did not (default_flag = 0).
